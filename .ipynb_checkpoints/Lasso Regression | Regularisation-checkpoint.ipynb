# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, roc_curve, mean_absolute_error
from sklearn.decomposition import PCA

# %%
X,y = fetch_california_housing(return_X_y=True)

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
X[0]
# Out:
# array([   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#         322.        ,    2.55555556,   37.88      , -122.23      ])

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
X_train.shape
# Out:
# (16512, 8)

# %%
y_train.shape
# Out:
# (16512,)

# %%
linear = LinearRegression()
linear.fit(X_train,y_train)
y_pred_linear = linear.predict(X_test)
r2_score(y_test,y_pred_linear)
# Out:
# 0.5989628208542918

# %%
X_train.shape
# Out:
# (16512, 8)

# %%
y_train.shape
# Out:
# (16512,)

# %%
pca = PCA(n_components=2)
# X_train_trans = pca.fit(X_train)

X_trans = pca.fit_transform(X)

# %%
X_trans.shape
# Out:
# (20640, 2)

# %%
type(X_trans)
# Out:
# numpy.ndarray

# %%
df_X = pd.DataFrame(X_trans)
df_y = pd.DataFrame(y)

# %%
df_X.columns = [['a','b']]

# %%
df_X.shape
# Out:
# (20640, 2)

# %%
df_y.shape
# Out:
# (20640, 1)

# %%
df_y.iloc[:,0]
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: 0, Length: 20640, dtype: float64

# %%
# fig = plt.figure(figsize=(10,5))
# ax = plt.subplot(1,2,1)

import plotly.express as px
px.scatter_3d(x=df_X.iloc[:,0],y=df_X.iloc[:,1],z=df_y.iloc[:,0])
# Out:
# <div>                            <div id="6cdb4165-592e-4dd3-b86a-91cb8db80bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cdb4165-592e-4dd3-b86a-91cb8db80bce")) {                    Plotly.newPlot(                        "6cdb4165-592e-4dd3-b86a-91cb8db80bce",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1103.5126482054734,975.5412444150006,-929.5499081237814,-867.550048044074,-860.5504106845889,-1012.5493338978388,-331.5532299631325,-268.553791716352,-219.52092280093245,125.44419750081684,-515.5521961401473,78.44440836462167,-327.5531850417327,-1080.5489391085853,-213.5539249302829,-728.5439744147247,-632.5515247146571,-777.5505719518878,-435.5459882364724,-735.5507930461616,-1016.5095798171491,-496.5190556552767,-410.5528349337379,-572.5516034261776,-419.55263462912006,-1108.5122088893463,-818.5403113122211,-323.55286209416283,-294.5466268129847,-1030.5489811106777,-562.5419892248574,-257.55333175446174,-399.53922796395415,-671.5413576697179,-167.5507466875517,-855.5403287331615,-438.5391331971283,-524.5519012135787,-736.5508432619773,-48.554715930039045,-479.5521215498009,-908.546538113367,-