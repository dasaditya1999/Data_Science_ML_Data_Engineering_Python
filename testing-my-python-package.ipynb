# %%
import sys
sys.version
# Out:
# '3.11.4 (main, Jul  5 2023, 08:54:11) [Clang 14.0.6 ]'

# %%
# !pip install database-automation-ioklj==0.0.5

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ------------
# absl-py                       2.0.0
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.0
# anaconda-navigator            2.4.2
# anaconda-project              0.11.1
# annotated-types               0.5.0
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# ...

# %%
import ensure

# %%
import database_automation

# %%
from database_automation import mongo_crud

# %%
object1 = mongo_crud.MongoDBOperation()

# %%
uri = "mongodb+srv://dasaditya576:OQu5FLiP7JP0vtH3@database1.ujpxq7w.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

databaseName = 'Database1'

collectionName = 'BankCustomerChurn'

# %%
result = object1.get_collection(uri, databaseName, collectionName)

# %%
for document in result.find():
    print(document)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for document in result.find():
#       2     print(document)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/cursor.py:1207, in Cursor.next(self)
#    1205 if self.__empty:
#    1206     raise StopIteration
# -> 1207 if len(self.__data) or self._refresh():
#    1208     if self.__manipulate:
#    1209         _db = self.__collection.database
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/cursor.py:1100, in Cursor._refresh(self)
#    1097     return len(self.__data)
#    1099 if not self.__session:
# -> 1100     self.__session = self.__collection.database.client._ensure_session()
#    1102 if self.__id is None:  # Query
#    1103     if (self.__min or self.__max) and not self.__hint:
#
# ...
